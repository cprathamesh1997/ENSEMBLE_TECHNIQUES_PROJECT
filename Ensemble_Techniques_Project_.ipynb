# %% [markdown]
# ## **Prediction Of Breast Cancer in Patients Using Ensemble Techniques**

# %% [markdown]
# ***This project aims to classify whether a patient has breast cancer or not based on the details of cell nuclei taken from breast mass using ensembling techniques like 'Bagging meta-estimator', 'AdaBoost', and 'XGBoost'. The dataset consists of several predictor variables and one target variable, Diagnosis, which has values 'Benign' and 'Malignant'.***
#
# ***Benign: These tumors are not cancerous. They do not invade nearby tissue or spread to other parts of the body. If a doctor removes them, they do not generally return.***
#
# ***Malignant: Malignant tumors are cancerous. The cells can grow and spread to other parts of the body.***
#
# ***Before building the model, necessary exploratory data analysis is performed to understand the data and identify any patterns or trends that could be useful for modeling.The performance of the model is evaluated based on performance metrics other than model accuracy.***

# %% [markdown]
# ### **READ THE DATASET**

# %%
#importing important packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
#reading the dataset
df=pd.read_csv("cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### **LABEL ENCODING USING MAP FUNCTION**

# %%
df['diagnosis'] = df['diagnosis'].map({'B':0, 'M':1})

# %% [markdown]
# ### **DIMENSIONS AND DATA TYPES**

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ### **Drop Not Required Columns**

# %%
df.drop(["Unnamed: 32"],axis=1,inplace=True)

# %%
df.drop(["id"],axis=1,inplace=True)

# %% [markdown]
# ## **If Any Missing Values**

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### **STATISTICAL SUMMARY**

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.quantile(0.25)
# Out:
# diagnosis                    0.000000
# radius_mean                 11.700000
# texture_mean                16.170000
# perimeter_mean              75.170000
# area_mean                  420.300000
# smoothness_mean              0.086370
# compactness_mean             0.064920
# concavity_mean               0.029560
# concave points_mean          0.020310
# symmetry_mean                0.161900
# fractal_dimension_mean       0.057700
# radius_se                    0.232400
# texture_se                   0.833900
# perimeter_se                 1.606000
# area_se                     17.850000
# smoothness_se                0.005169
# compactness_se               0.013080
# concavity_se                 0.015090
# concave points_se            0.007638
# symmetry_se                  0.015160
# fractal_dimension_se         0.002248
# radius_worst                13.010000
# texture_worst               21.080000
# perimeter_worst             84.110000
# area_worst                 515.300000
# ...

# %%
df.quantile(0.75)
# Out:
# diagnosis                     1.000000
# radius_mean                  15.780000
# texture_mean                 21.800000
# perimeter_mean              104.100000
# area_mean                   782.700000
# smoothness_mean               0.105300
# compactness_mean              0.130400
# concavity_mean                0.130700
# concave points_mean           0.074000
# symmetry_mean                 0.195700
# fractal_dimension_mean        0.066120
# radius_se                     0.478900
# texture_se                    1.474000
# perimeter_se                  3.357000
# area_se                      45.190000
# smoothness_se                 0.008146
# compactness_se                0.032450
# concavity_se                  0.042050
# concave points_se             0.014710
# symmetry_se                   0.023480
# fractal_dimension_se          0.004558
# radius_worst                 18.790000
# texture_worst                29.720000
# perimeter_worst             125.400000
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# diagnosis                    1.000000
# radius_mean                  4.080000
# texture_mean                 5.630000
# perimeter_mean              28.930000
# area_mean                  362.400000
# smoothness_mean              0.018930
# compactness_mean             0.065480
# concavity_mean               0.101140
# concave points_mean          0.053690
# symmetry_mean                0.033800
# fractal_dimension_mean       0.008420
# radius_se                    0.246500
# texture_se                   0.640100
# perimeter_se                 1.751000
# area_se                     27.340000
# smoothness_se                0.002977
# compactness_se               0.019370
# concavity_se                 0.026960
# concave points_se            0.007072
# symmetry_se                  0.008320
# fractal_dimension_se         0.002310
# radius_worst                 5.780000
# texture_worst                8.640000
# perimeter_worst             41.290000
# area_worst                 568.700000
# ...

# %%
threshold = 1.5 * IQR
outliers = df[(df < Q1 - threshold) | (df > Q3 + threshold)]
outliers
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          NaN          NaN           NaN             NaN        NaN
# 1          NaN          NaN           NaN             NaN        NaN
# 2          NaN          NaN           NaN             NaN        NaN
# 3          NaN          NaN           NaN             NaN        NaN
# 4          NaN          NaN           NaN             NaN        NaN
# ..         ...          ...           ...             ...        ...
# 564        NaN          NaN           NaN             NaN     1479.0
# 565        NaN          NaN           NaN             NaN        NaN
# 566        NaN          NaN           NaN             NaN        NaN
# 567        NaN          NaN           NaN             NaN        NaN
# 568        NaN          NaN           NaN             NaN        NaN
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ## **EDA Or VISUALIZATION**

# %%
#Count comparison for target variable
df['diagnosis']=pd.Categorical(df['diagnosis'])
sns.countplot(x = 'diagnosis', data =df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df2 = df.drop(['diagnosis'],axis=1)

# %%
#PDF's of Features
fig=df.hist(figsize= (18,18))

# %% [markdown]
# **Below Bar Plots basically shows how much each feature effects the value of the target variable.
# For E.g We can see for "radius_mean" it has much more effect on the value '1' as compared to '0'.**

# %%
for i in df2.columns:
 plt.figure(figsize=(15,6))
 sns.barplot(x = df['diagnosis'], y = df2[i], data = df, palette = 'hls')
 plt.show()

# %% [markdown]
# ## **CORRELATION**

# %% [markdown]
# **Correlation is a statistical measure that describes the strength and direction of a relationship between two variables. In other words, it is a measure of how closely two variables are related to each other**.

# %%
df.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
list(df.columns)
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
import plotly.graph_objs as go
from plotly.graph_objs import *
cols=['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
trace1 = go.Heatmap( 
  x= df[cols].corr().columns.tolist(), 
  y= df[cols].corr().columns.tolist(), 
  z= df[cols].corr().values.tolist(),
)
fig = go.Figure(data=[trace1])
fig.update_layout(height=700,
    width=800,template='plotly_dark',
                  title={'text':"Features Correlation HeatMap",
                         'xanchor': 'center',
                         'yanchor': 'top',
                         'x':0.5,'y':0.9})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **By carefully looking at the correlation plot we can say that 'radius_mean', 'perimeter_mean','compactness_mean','concave points_mean',
# 'radius_se','perimeter_se','compactness_se', 'concave points_se', 'radius_worst', 'texture_worst','perimeter_worst','compactness_worst','area worst', 'concave points_worst' have a strong positive correlation with each other.Therefore,we can also not select these features together for training model if required.**

# %%
drop_list=['radius_mean', 'perimeter_mean','compactness_mean','concave points_mean', 'radius_se','perimeter_se','compactness_se', 'concave points_se', 'radius_worst', 'texture_worst','perimeter_worst','compactness_worst','area_worst', 'concave points_worst']
df_clean = df.drop(drop_list,axis = 1)
df_clean.head()
# Out:
#    diagnosis  texture_mean  area_mean  smoothness_mean  concavity_mean  \
# 0          1         10.38     1001.0          0.11840          0.3001
# 1          1         17.77     1326.0          0.08474          0.0869
# 2          1         21.25     1203.0          0.10960          0.1974
# 3          1         20.38      386.1          0.14250          0.2414
# 4          1         14.34     1297.0          0.10030          0.1980
#
#    symmetry_mean  fractal_dimension_mean  texture_se  area_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053   153.40       0.006399
# 1         0.1812                 0.05667      0.7339    74.08       0.005225
# 2         0.2069                 0.05999      0.7869    94.03       0.006150
# 3         0.2597                 0.09744      1.1560    27.23       0.009110
# 4         0.1809                 0.05883      0.7813    94.44       0.011490
#
#    concavity_se  symmetry_se  fractal_dimension_se  smoothness_worst  \
# ...

# %% [markdown]
# ### **SPLITTING AND SCALING DATA**

# %%
#Split_the_data
#Tools provided by scikit-learn to aid in the process of building and evaluating machine learning models.
from sklearn.model_selection import train_test_split,cross_val_score, KFold, GridSearchCV

X=df_clean.drop(['diagnosis'],axis=1)
y=df['diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
X_train.shape, X_test.shape
# Out:
# ((426, 16), (143, 16))

# %% [markdown]
# ***Standardizing the features is an important preprocessing step that is often performed before fitting a machine learning model. It helps to ensure that all features are on the same scale, which can prevent certain features from dominating the model fitting process due to their larger scale.***

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# ### **FURTHER USING OF ENSEMBLE TECHNIQUES FOR PREDICTION AND EVALUATION METRICS**

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# ***We are training a decision tree classifier using scikit-learn and performing a grid search to find the best value of the hyperparameter 'max_depth'***

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=5)
max_depth_range = list(range(1, 31))
param_grid = dict(max_depth=max_depth_range)
grid = GridSearchCV(dt, param_grid, cv=10, scoring='f1', return_train_score=False)
grid.fit(X_train_std, y_train)
grid_mean_scores = grid.cv_results_['mean_test_score']
plt.plot(max_depth_range, grid_mean_scores)
plt.xlabel('Value of max_depth for Decision Tree')
plt.ylabel('Cross-Validated')
print(grid.best_score_)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# 0.8895680459574983
# {'max_depth': 6}
# DecisionTreeClassifier(max_depth=6, random_state=5)

# %%
#For_Bagging_Classifier

import warnings
warnings.filterwarnings('ignore')

base_model = tree.DecisionTreeClassifier(max_depth = 6,random_state=5)
modelb = BaggingClassifier(estimator=base_model)
modelb.fit(X_train_std, y_train)
y_pred = modelb.predict(X_test_std)

bagging_acc = accuracy_score(y_test, y_pred)

print("Accuracy of Bagging model is: ", bagging_acc)
modelb.score(X_test_std,y_test)

bagging_f1 = f1_score(y_test, y_pred)
bagging_cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix of Bagging model is: \n", bagging_cm)
print("F1 score of Bagging model is: ", bagging_f1)

cmap = 'summer'
display_labels=['Benign','Malignant']
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=cmap)
plt.show()
# Out:
# Accuracy of Bagging model is:  0.951048951048951
# Confusion matrix of Bagging model is:
#  [[86  2]
#  [ 5 50]]
# F1 score of Bagging model is:  0.9345794392523366

# %% [markdown]
# *TP: 50 positive cases correctly predicted*
#
# *TN: 86 negative cases correctly predicted*
#
# *FP: 2 negative cases are misclassified (wrong positive predictions)*
#
# *FN: 5 positive cases are misclassified (wrong negative predictions)*

# %%
#For_AdaBoost_Classifier

modela = AdaBoostClassifier()
modela.fit(X_train_std, y_train)
y_pred = modela.predict(X_test_std)
ada_acc = accuracy_score(y_test, y_pred)

print("Accuracy of AdaBoost model is: ", ada_acc)
modela.score(X_test_std,y_test)

ada_f1 = f1_score(y_test, y_pred)
ada_cm = confusion_matrix(y_test, y_pred)

print("Confusion matrix of AdaBoost model is: \n", ada_cm)
print("F1 score of AdaBoost model is: ", ada_f1)

cmap = 'summer'
display_labels=['Benign','Malignant']
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=cmap)
plt.show()
# Out:
# Accuracy of AdaBoost model is:  0.986013986013986
# Confusion matrix of AdaBoost model is:
#  [[88  0]
#  [ 2 53]]
# F1 score of AdaBoost model is:  0.9814814814814815

# %% [markdown]
# *TP: 53 positive cases correctly predicted*
#
# *TN: 88 negative cases correctly predicted*
#
# *FP: 0 negative cases are misclassified (wrong positive predictions)*
#
# *FN: 2 positive cases are misclassified (wrong negative predictions)*

# %%
#For_XGBClassifier

modelx = XGBClassifier()
modelx.fit(X_train_std, y_train)
y_pred = modelx.predict(X_test_std)

xgb_acc = accuracy_score(y_test, y_pred)
print("Accuracy of XGBoost model is: ", xgb_acc)

xgb_f1 = f1_score(y_test, y_pred)
xgb_cm = confusion_matrix(y_test, y_pred)

print("Confusion matrix of XGBoost model is: \n", xgb_cm)
print("F1 score of XGBoost model is: ", xgb_f1)
print(modelx.feature_importances_)

cmap = 'summer'
display_labels=['Benign','Malignant']
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=cmap)
plt.show()
# Out:
# Accuracy of XGBoost model is:  0.972027972027972
# Confusion matrix of XGBoost model is:
#  [[87  1]
#  [ 3 52]]
# F1 score of XGBoost model is:  0.9629629629629629
# [0.03173869 0.08421484 0.02929702 0.50556946 0.00579858 0.00987702
#  0.01927371 0.05382389 0.02289158 0.02749278 0.00378775 0.02287235
#  0.04542769 0.10783847 0.01401155 0.01608461]

# %% [markdown]
# *TP: 52 positive cases correctly predicted*
#
# *TN: 87 negative cases correctly predicted*
#
# *FP: 1 negative cases are misclassified (wrong positive predictions)*
#
# *FN: 3 positive cases are misclassified (wrong negative predictions)*

# %%
X_train_std_df = pd.DataFrame(X_train_std, columns=X_train.columns)
print(X_train_std_df.columns)
# Out:
# Index(['texture_mean', 'area_mean', 'smoothness_mean', 'concavity_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_se',
#        'smoothness_se', 'concavity_se', 'symmetry_se', 'fractal_dimension_se',
#        'smoothness_worst', 'concavity_worst', 'symmetry_worst',
#        'fractal_dimension_worst'],
#       dtype='object')

# %%
feat_importances = pd.Series(modelx.feature_importances_,index=X_train_std_df.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ## **MODEL PERFORMANCE COMPARISON USING AUROC**

# %%
from sklearn.metrics import RocCurveDisplay,DetCurveDisplay

models = {'Bagging_classifier':modelb,'ADA_boost':modela,'XG_boost':modelx}
fig, [ax_roc, ax_det] = plt.subplots(1, 2, figsize=(11,5))


for name, clf in models.items():
    clf.fit(X_train_std, y_train)
    RocCurveDisplay.from_estimator(clf, X_test_std, y_test, ax=ax_roc, name=name)
    DetCurveDisplay.from_estimator(clf, X_test_std, y_test, ax=ax_det, name=name)
    
ax_roc.set_title("Receiver Operating Characteristic (ROC) curves")
ax_det.set_title("Detection Error Tradeoff (DET) curves")

ax_roc.grid(linestyle="--")
ax_det.grid(linestyle="--")



plt.legend()
plt.show()

# %% [markdown]
# ***The DET curve is useful for evaluating the performance of a binary classifier when both the FNR and FPR are important, and the optimal point on the DET curve is the point with the minimum value of the convex combination of the FNR and FPR.***

# %% [markdown]
# ### **MODEL PERFORMANCE COMPARISON USING BAR GRAPH FOR F1 SCORE AND ACCURACY**

# %%
import plotly.graph_objects as go

models = ['Bagging', 'AdaBoost', 'XGBoost']
accuracy_scores = [bagging_acc, ada_acc, xgb_acc]
f1_scores = [bagging_f1, ada_f1, xgb_f1]

fig = go.Figure(data=[
    go.Bar(name='Accuracy', x=models, y=accuracy_scores),
    go.Bar(name='F1 Score', x=models, y=f1_scores)
])

fig.update_layout(barmode='group', title_text='Comparison of Model Performance', xaxis_title='Models', yaxis_title='Score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **SUMMARY**

# %% [markdown]
# ***Since our project is medical diagnosis we need to give maximum importance to Type II error in statistics(False Negative).False Negative is that the truth is positive, but the test predicts a negative. The person is sick, but the test inaccurately reports that they are not.Results show that ADaBoost was the most powerful prediction model than other ensemble machine learning techniques for Breast Cancer dataset.***
